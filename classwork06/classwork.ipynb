# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/aronlindberg/latent_growth_classes/master/LGC_data.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
def mnk(a,b):
    return (0,0)
x = np.linspace(1, 11, 11)

k = 10
epsilon = np.random.normal(0, 1e-1 * k, size=x.shape)
F = k * x + epsilon

x_err = 0.5
y_err = k * x_err

k_approx, b_approx = mnk(x, F)

x_expand = np.array([0, 12])

plt.plot(x_expand, k_approx * x_expand + b_approx, linestyle="--", label="Approx")
plt.errorbar(x, F, xerr=x_err, yerr=y_err, linestyle="none")

plt.scatter(x, F, s=10, marker="^", label="DATA", color="black")

plt.xlabel("x, cm")
plt.ylabel(r"$\mathcal{F}, N$", rotation=0)

plt.xlim(0, 12)
plt.ylim(0, 120)

plt.grid()
plt.minorticks_on()
plt.grid(which="minor", linestyle=":")

plt.legend()

plt.title(r"Measurement of spring, $\mathcal{F} = k \cdot x$")
plt.tight_layout()
plt.savefig("output.pdf")

plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   top100_repository_name  1000 non-null   object
#  1   month                   1000 non-null   object
#  2   monthly_increase        1000 non-null   int64
#  3   monthly_begin_at        1000 non-null   int64
#  4   monthly_end_with        1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 31.3+ KB

# %%
df.describe()
# Out:
#        monthly_increase  monthly_begin_at  monthly_end_with
# count       1000.000000       1000.000000       1000.000000
# mean         479.845000        571.841000       1051.686000
# std         1194.824221        767.743174       1264.877638
# min            1.000000         11.000000         61.000000
# 25%           22.000000         25.000000        513.000000
# 50%           63.500000        467.500000        696.000000
# 75%          578.500000        715.250000       1016.500000
# max        10844.000000       9219.000000      10869.000000

# %%
((df.monthly_increase.mean()-df.monthly_increase)**2/(df.shape[0]-1)).sum()**0.5
# Out:
# 1194.8242213375552

# %%
df[df.top100_repository_name == 'zf2'].plot(x='month')
df.monthly_increase[df.top100_repository_name == 'zf2']
# Out:
# 990     27
# 991     52
# 992     60
# 993     64
# 994     60
# 995     68
# 996    204
# 997    128
# 998     92
# 999     56
# Name: monthly_increase, dtype: int64

# %%
df.groupby(by=['month']).agg({'monthly_increase':'mean'})
# Out:
#          monthly_increase
# month
# 2012-03            313.11
# 2012-04            345.44
# 2012-05            341.52
# 2012-06            441.13
# 2012-07            508.26
# 2012-08            433.46
# 2012-09            485.96
# 2012-10            646.10
# 2012-11            655.84
# 2012-12            627.63

# %%
df.sort_values(by=['month'])
#df[df.month == '2012-12']['monthly_increase'].mean()
# Out:
#     top100_repository_name    month  monthly_increase  monthly_begin_at  \
# 0                   Bukkit  2012-03                 9               431
# 650                   node  2012-03                63              1567
# 260               cucumber  2012-03                10               405
# 800            refinerycms  2012-03                25               602
# 640                mongoid  2012-03                14               582
# ..                     ...      ...               ...               ...
# 629              linux-2.6  2012-12                 2               507
# 639                 mangos  2012-12                53                12
# 649                mongoid  2012-12                 9               749
# 669              octopress  2012-12              1430                12
# 999                    zf2  2012-12                56              1480
#
#      monthly_end_with
# 0                 440
# 650              1630
# 260               415
# ...

# %%
# Out:
#   Cell In[51], line 1
#     f.nunique()?
#                ^
# SyntaxError: invalid syntax
